# %% [markdown]
# #### 영화 정보

# %%
import pandas as pd

m_cols = ['movie_id', 'title', 'genre']
movies = pd.read_csv('../recommend/ml-10M100K/movies.dat', names=m_cols, sep='::', engine='python')

movies['genre'] = movies['genre'].apply(lambda x: x.split('|'))
movies.head()
# Out:
#    movie_id                               title  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                                                genre
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                     [Adventure, Children, Fantasy]
# 2                                  [Comedy, Romance]
# 3                           [Comedy, Drama, Romance]
# 4                                           [Comedy]

# %% [markdown]
# #### 태그 정보

# %%
import pandas as pd

t_cols = ['user_id', 'movie_id', 'tag', 'timestamp']
user_tagged_movies = pd.read_csv('../recommend/ml-10M100K/tags.dat', names=t_cols, sep='::', engine='python')

user_tagged_movies['tag'] = user_tagged_movies['tag'].str.lower()

user_tagged_movies.head()
# Out:
#    user_id  movie_id              tag   timestamp
# 0       15      4973       excellent!  1215184630
# 1       20      1747         politics  1188263867
# 2       20      1747           satire  1188263867
# 3       20      2424  chick flick 212  1188263835
# 4       20      2424            hanks  1188263835

# %%
import pandas as pd

t_cols = ['user_id', 'movie_id', 'tag', 'timestamp']
user_tagged_movies = pd.read_csv('../recommend/ml-10M100K/tags.dat', names=t_cols, sep='::', engine='python')

print(f'태그 종류={len(user_tagged_movies.tag.unique())}')
print(f'태그 레코드 수={len(user_tagged_movies)}')
print(f'태그가 붙어 있는 영화 수={len(user_tagged_movies.movie_id.unique())}')
# Out:
# 태그 종류=16529
# 태그 레코드 수=95580
# 태그가 붙어 있는 영화 수=7601

# %%
import pandas as pd

t_cols = ['user_id', 'movie_id', 'tag', 'timestamp']
user_tagged_movies = pd.read_csv('../recommend/ml-10M100K/tags.dat', names=t_cols, sep='::', engine='python')

movie_tags = user_tagged_movies.groupby('movie_id').agg({'tag':list})
movies = movies.merge(movie_tags, on='movie_id', how='left')
movies.head()
# Out:
#    movie_id                               title  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                                                genre  \
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                     [Adventure, Children, Fantasy]
# 2                                  [Comedy, Romance]
# 3                           [Comedy, Drama, Romance]
# 4                                           [Comedy]
#
#                                                  tag
# 0  [Pixar, Pixar, Pixar, animation, Pixar, animat...
# 1  [For children, game, animals, Joe Johnston, Ro...
# 2  [Funniest Movies, comedinha de velhinhos engra...
# 3                                       [girl movie]
# 4  [steve martin, pregnancy, remake, steve martin...

# %% [markdown]
# #### 평가값 데이터

# %%
import pandas as pd

r_cols = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_csv('../recommend/ml-10M100K/ratings.dat', names=r_cols, sep='::', engine='python')
ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1       122     5.0  838985046
# 1        1       185     5.0  838983525
# 2        1       231     5.0  838983392
# 3        1       292     5.0  838983421
# 4        1       316     5.0  838983392

# %%
import pandas as pd

r_cols = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_csv('../recommend/ml-10M100K/ratings.dat', names=r_cols, sep='::', engine='python')
valid_user_ids = sorted(ratings.user_id.unique())[:1000]
ratings = ratings[ratings['user_id'].isin(valid_user_ids)]

m_cols = ['movie_id', 'title', 'genre']
movies = pd.read_csv('../recommend/ml-10M100K/movies.dat', names=m_cols, sep='::', engine='python')

movies['genre'] = movies['genre'].apply(lambda x: x.split('|'))

movielens = ratings.merge(movies, on='movie_id')
movielens.head()
# Out:
#    user_id  movie_id  rating  timestamp                 title  \
# 0        1       122     5.0  838985046      Boomerang (1992)
# 1        1       185     5.0  838983525       Net, The (1995)
# 2        1       231     5.0  838983392  Dumb & Dumber (1994)
# 3        1       292     5.0  838983421       Outbreak (1995)
# 4        1       316     5.0  838983392       Stargate (1994)
#
#                                genre
# 0                  [Comedy, Romance]
# 1          [Action, Crime, Thriller]
# 2                           [Comedy]
# 3  [Action, Drama, Sci-Fi, Thriller]
# 4        [Action, Adventure, Sci-Fi]

# %% [markdown]
# #### 사용자

# %%
import pandas as pd
import numpy as np

r_cols = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_csv('../recommend/ml-10M100K/ratings.dat', names=r_cols, sep='::', engine='python')
valid_user_ids = sorted(ratings.user_id.unique())[:1000]
ratings = ratings[ratings['user_id'].isin(valid_user_ids)]

m_cols = ['movie_id', 'title', 'genre']
movies = pd.read_csv('../recommend/ml-10M100K/movies.dat', names=m_cols, sep='::', engine='python')

movies['genre'] = movies['genre'].apply(lambda x: x.split('|'))

movielens = ratings.merge(movies, on='movie_id')

movielens.groupby('user_id').agg({'movie_id': len}).agg({'movie_id':[min, max, np.mean, len]})
# Out:
# /var/folders/t9/33ffj14107j841h1k11yd5n00000gn/T/ipykernel_24582/2755499644.py:16: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   movielens.groupby('user_id').agg({'movie_id': len}).agg({'movie_id':[min, max, np.mean, len]})
# /var/folders/t9/33ffj14107j841h1k11yd5n00000gn/T/ipykernel_24582/2755499644.py:16: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   movielens.groupby('user_id').agg({'movie_id': len}).agg({'movie_id':[min, max, np.mean, len]})
# /var/folders/t9/33ffj14107j841h1k11yd5n00000gn/T/ipykernel_24582/2755499644.py:16: FutureWarning: The provided callable <function mean at 0x105a05e50> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   movielens.groupby('user_id').agg({'movie_id': len}).agg({'movie_id':[min, max, np.mean, len]})
#    user_id  movie_id  rating  timestamp                 title  \
# 0        1       122     5.0  838985046      Boomerang (1992)
# 1        1       185     5.0  838983525       Net, The (1995)
# 2        1       231     5.0  838983392  Dumb & Dumber (1994)
# 3        1       292     5.0  838983421       Outbreak (1995)
# 4        1       316     5.0  838983392       Stargate (1994)
#
#                                genre
# 0                  [Comedy, Romance]
# 1          [Action, Crime, Thriller]
# 2                           [Comedy]
# 3  [Action, Drama, Sci-Fi, Thriller]
# 4        [Action, Adventure, Sci-Fi]

# %%
import pandas as pd

r_cols = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_csv('../recommend/ml-10M100K/ratings.dat', names=r_cols, sep='::', engine='python')

m_cols = ['movie_id', 'title', 'genre']
movies = pd.read_csv('../recommend/ml-10M100K/movies.dat', names=m_cols, sep='::', engine='python')

movies['genre'] = movies['genre'].apply(lambda x: x.split('|'))

movielens = ratings.merge(movies, on='movie_id')
print(f'평가값 수 ={len(movielens)}')
movielens.groupby('rating').agg({'movie_id':len})
# Out:
# 평가값 수 =10000054
#         movie_id
# rating
# 0.5        94988
# 1.0       384180
# 1.5       118278
# 2.0       790306
# 2.5       370178
# 3.0      2356676
# 3.5       879764
# 4.0      2875850
# 4.5       585022
# 5.0      1544812

# %%
import pandas as pd

r_cols = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_csv('../recommend/ml-10M100K/ratings.dat', names=r_cols, sep='::', engine='python')

m_cols = ['movie_id', 'title', 'genre']
movies = pd.read_csv('../recommend/ml-10M100K/movies.dat', names=m_cols, sep='::', engine='python')

movies['genre'] = movies['genre'].apply(lambda x: x.split('|'))

movielens = ratings.merge(movies, on='movie_id')

movielens['timestamp_rank'] = movielens.groupby('user_id')['timestamp'].rank(ascending=False, method='first')
movielens_train = movielens[movielens['timestamp_rank'] > 5]
movielens_test = movielens[movielens['timestamp_rank'] <= 5]

# %%
import pandas as pd
from typing import List
from sklearn.metrics import mean_squared_error



r_cols = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_csv('../recommend/ml-10M100K/ratings.dat', names=r_cols, sep='::', engine='python')

m_cols = ['movie_id', 'title', 'genre']
movies = pd.read_csv('../recommend/ml-10M100K/movies.dat', names=m_cols, sep='::', engine='python')

movies['genre'] = movies['genre'].apply(lambda x: x.split('|'))

movielens = ratings.merge(movies, on='movie_id')

movielens['timestamp_rank'] = movielens.groupby('user_id')['timestamp'].rank(ascending=False, method='first')
movielens_train = movielens[movielens['timestamp_rank'] > 5]
movielens_test = movielens[movielens['timestamp_rank'] <= 5]

# %%
# analyze_movielens.py

# 1. 라이브러리 불러오기
import pandas as pd
import numpy as np
import os
from typing import List
from sklearn.metrics import mean_squared_error

# RMSE 계산 함수 정의 (self 제거)
def calc_rmse(true_rating: List[float], pred_rating: List[float]) -> float:
    """
    실제 평점과 예측 평점 리스트를 받아 RMSE를 계산하는 함수
    """
    return np.sqrt(mean_squared_error(true_rating, pred_rating))


# --- 메인 스크립트 실행 ---
print("스크립트 실행 시작...")

# 2. 데이터 경로 설정
base_path = '../recommend/ml-10M100K/'
ratings_path = os.path.join(base_path, 'ratings.dat')
movies_path = os.path.join(base_path, 'movies.dat')

# 3. 데이터 불러오기
print(f"'{ratings_path}' 에서 ratings 데이터를 불러옵니다...")
r_cols = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_csv(ratings_path, names=r_cols, sep='::', engine='python')

print(f"'{movies_path}' 에서 movies 데이터를 불러옵니다...")
m_cols = ['movie_id', 'title', 'genre']
movies = pd.read_csv(movies_path, names=m_cols, sep='::', engine='python', encoding='latin-1')

# 4. 데이터 전처리
print("데이터 전처리를 시작합니다...")
movies['genre'] = movies['genre'].apply(lambda x: x.split('|'))
movielens = ratings.merge(movies, on='movie_id')

# 5. 훈련(Train) / 시험(Test) 데이터 분리
print("시간 순서에 따라 훈련/시험 데이터로 분리합니다...")
movielens['timestamp_rank'] = movielens.groupby('user_id')['timestamp'].rank(ascending=False, method='first')
movielens_train = movielens[movielens['timestamp_rank'] > 5]
movielens_test = movielens[movielens['timestamp_rank'] <= 5]

# 6. 예측값 생성 (Baseline 모델)
print("가장 기본적인 모델을 사용해 예측값을 생성합니다...")
# 훈련 데이터의 전체 평점 평균을 계산
global_mean = movielens_train['rating'].mean()
print(f"훈련 데이터의 전체 평균 평점: {global_mean:.4f}")

# 시험 데이터의 모든 예측값을 전체 평균 평점으로 채움
pred_rating = [global_mean] * len(movielens_test)

# 7. RMSE 계산 및 결과 출력
print("RMSE를 계산합니다...")
# 시험 데이터의 실제 평점 리스트
true_rating = movielens_test['rating'].tolist()

# calc_rmse 함수 호출
rmse = calc_rmse(true_rating, pred_rating)

# --- 최종 결과 출력 ---
print("\n--- 작업 완료 ---")
print(f"전체 평점 데이터 수: {len(movielens)}")
print(f"훈련 데이터 수 (Train set): {len(movielens_train)}")
print(f"시험 데이터 수 (Test set): {len(movielens_test)}")
print(f"\nBaseline 모델의 RMSE 결과: {rmse:.4f}")
print("-----------------")
# Out:
# 스크립트 실행 시작...
# '../recommend/ml-10M100K/ratings.dat' 에서 ratings 데이터를 불러옵니다...
# '../recommend/ml-10M100K/movies.dat' 에서 movies 데이터를 불러옵니다...
# 데이터 전처리를 시작합니다...
# 시간 순서에 따라 훈련/시험 데이터로 분리합니다...
# 가장 기본적인 모델을 사용해 예측값을 생성합니다...
# 훈련 데이터의 전체 평균 평점: 3.5088
# RMSE를 계산합니다...
#
# --- 작업 완료 ---
# 전체 평점 데이터 수: 10000054
# 훈련 데이터 수 (Train set): 9650664
# 시험 데이터 수 (Test set): 349390
#
# Baseline 모델의 RMSE 결과: 1.0794
# -----------------

# %%
# analyze_movielens.py

# 1. 라이브러리 불러오기
import pandas as pd
import os

print("스크립트 실행 시작...")

# 2. 데이터 경로 설정
# 이 스크립트 파일이 있는 폴더(scripts)를 기준으로 상대 경로를 설정합니다.
# ../는 상위 폴더를 의미합니다.
base_path = '../recommend/ml-10M100K/'
ratings_path = os.path.join(base_path, 'ratings.dat')
movies_path = os.path.join(base_path, 'movies.dat')

# 3. 데이터 불러오기
print(f"'{ratings_path}' 에서 ratings 데이터를 불러옵니다...")
r_cols = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_csv(ratings_path, names=r_cols, sep='::', engine='python')

print(f"'{movies_path}' 에서 movies 데이터를 불러옵니다...")
m_cols = ['movie_id', 'title', 'genre']
movies = pd.read_csv(movies_path, names=m_cols, sep='::', engine='python', encoding='latin-1') # 인코딩 추가

# 4. 데이터 전처리
print("데이터 전처리를 시작합니다...")
# 장르 데이터를 문자열 리스트로 변환
movies['genre'] = movies['genre'].apply(lambda x: x.split('|'))

# ratings 데이터와 movies 데이터 병합
movielens = ratings.merge(movies, on='movie_id')

# 5. 훈련(Train) / 시험(Test) 데이터 분리
print("시간 순서에 따라 훈련/시험 데이터로 분리합니다...")
# 각 사용자별로 timestamp를 기준으로 최신 순으로 순위(rank) 매기기
movielens['timestamp_rank'] = movielens.groupby('user_id')['timestamp'].rank(ascending=False, method='first')

# 가장 최근 5개를 제외한 나머지를 훈련 데이터로 사용
movielens_train = movielens[movielens['timestamp_rank'] > 5]

# 가장 최근 5개를 시험 데이터로 사용
movielens_test = movielens[movielens['timestamp_rank'] <= 5]

# 6. 결과 확인
print("\n--- 작업 완료 ---")
print(f"전체 평점 데이터 수: {len(movielens)}")
print(f"훈련 데이터 수 (Train set): {len(movielens_train)}")
print(f"시험 데이터 수 (Test set): {len(movielens_test)}")
print(f"훈련 데이터 샘플:\n{movielens_train.head()}")
print(f"\n시험 데이터 샘플:\n{movielens_test.head()}")
print("-----------------")
# Out:
# 스크립트 실행 시작...
# '../recommend/ml-10M100K/ratings.dat' 에서 ratings 데이터를 불러옵니다...
# '../recommend/ml-10M100K/movies.dat' 에서 movies 데이터를 불러옵니다...
# 데이터 전처리를 시작합니다...
# 시간 순서에 따라 훈련/시험 데이터로 분리합니다...
#
# --- 작업 완료 ---
# 전체 평점 데이터 수: 10000054
# 훈련 데이터 수 (Train set): 9650664
# 시험 데이터 수 (Test set): 349390
# 훈련 데이터 샘플:
#    user_id  movie_id  rating  timestamp                          title  \
# 1        1       185     5.0  838983525                Net, The (1995)
# 2        1       231     5.0  838983392           Dumb & Dumber (1994)
# 3        1       292     5.0  838983421                Outbreak (1995)
# 4        1       316     5.0  838983392                Stargate (1994)
# 5        1       329     5.0  838983392  Star Trek: Generations (1994)
#
#                                 genre  timestamp_rank
# 1           [Action, Crime, Thriller]            17.0
# 2                            [Comedy]            19.0
# 3   [Action, Drama, Sci-Fi, Thriller]            18.0
# 4         [Action, Adventure, Sci-Fi]            20.0
# 5  [Action, Adventure, Drama, Sci-Fi]            21.0
#
# 시험 데이터 샘플:
#     user_id  movie_id  rating  timestamp                             title  \
# 0         1       122     5.0  838985046                  Boomerang (1992)
# 8         1       362     5.0  838984885           Jungle Book, The (1994)
# 13        1       466     5.0  838984679       Hot Shots! Part Deux (1993)
# 15        1       520     5.0  838984679  Robin Hood: Men in Tights (1993)
# 21        1       616     5.0  838984941            Aristocats, The (1970)
#
#                              genre  timestamp_rank
# 0                [Comedy, Romance]             1.0
# 8   [Adventure, Children, Romance]             3.0
# 13           [Action, Comedy, War]             4.0
# 15                        [Comedy]             5.0
# 21           [Animation, Children]             2.0
# -----------------
